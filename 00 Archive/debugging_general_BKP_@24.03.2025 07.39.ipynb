# %%
from data_fetcher import DataFetcher
from trading import Strategies 
import pandas as pd 
import numpy as np 
from binance.client import Client


import gym
from gym import spaces

# %% [markdown]
# # Class for Strategies
#
# #### Following, the class created for create the strategies

# %% [markdown]
# First two cells below are to visualize how the strategy can be written

# %%
#################################### Class for fetching data 


import pandas as pd
import numpy as np
from binance.client import Client
from utils import get_interval_from_string #for the mapping of the interval




class DataFetcher:
    """
    A class to fetch historical candlestick data from the Binance API.
    
    The DataFetcher class allows you to retrieve market data from a specified client and 
    for a specified symbol.

    Attributes:
        client (Client): The Binance API client used for making requests.
        symbol (str): The market symbol to fetch data for (e.g., "BTCUSDT").


    Methods:
        __init__(client, symbol):
            Initializes the DataFetcher with the specified parameters.
        
        get_interval_from_string(interval_str):
            Converts a user-friendly interval string (e.g., "1DAY") into the corresponding Binance constant.
        
        fetch_data(interval, start_date, end_date):
            Fetches the historical candlestick data and returns it as a pandas DataFrame.

        Other functions will be documented in the memo 
    """


    # Now I can initiate the class
    def __init__(self, client, symbol):
        """
        Initializes the DataFetcher instance with the provided parameters.

        Parameters:
            client (Client): The Binance API client instance used for fetching data.
            symbol (str): The symbol for which to fetch the historical data (e.g., "BTCUSDT").
        
        """
        self.client = client
        self.symbol = symbol




    def fetch_data(self, interval, start_date, end_date):
        """
        Fetches the historical candlestick data for the specified symbol, interval, and date range.
        
        This method calls the Binance API and converts the raw data into a pandas DataFrame.
        
        Parameters: 
            interval (str): this is a string identifying the time interval you want to dowload the data (e.g 1DAY)
            start_date (str): Starting date from which you want to download the data, in Binance format (e.g. "1 Jan, 2025")
            end_date (str): Ending date until which you want to download the data, in Binance format (e.g. "3 Jan, 2025")
        
        Returns:
            pd.DataFrame: A pandas DataFrame containing the candlestick data with columns
                          ['timestamp', 'open', 'high', 'low', 'close', 'volume'].
        """
        # Fetch historical klines
        candles = self.client.get_historical_klines(self.symbol, get_interval_from_string(interval), 
                                                    start_date, end_date)
        
        # Convert to DataFrame
        columns = ['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 
                   'quote_asset_volume', 'number_of_trades', 'taker_buy_base', 'taker_buy_quote', 'ignore']
        df = pd.DataFrame(candles, columns= columns)
        
        # Process DataFrame
        df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
        df.set_index('timestamp', inplace=True)
        df = df[['open', 'high', 'low', 'close', 'volume']].astype(float)
        return df
    # End of fetch_data() ----------------------------------------------------------------------------------------------------------


    def fetch_VWAP(self, interval, start_date, end_date):
        """
        Fetches the historical candlestick data and calculates the Volume Weighted Average Price (VWAP).
        
        This function retrieves the market data using the `fetch_data` method of the `DataFetcher` class, 
        then calculates the VWAP using the formula: VWAP = (Price * Volume) / Volume, where Price is the typical price 
        (average of high, low, and close).

        Parameters:
            interval (str): The time interval for the candlestick data (e.g., "1DAY", "1HOUR").
            start_date (str): The starting date for the data retrieval (e.g., "1 Jan, 2025").
            end_date (str): The ending date for the data retrieval (e.g., "3 Jan, 2025").

        Returns:
            pd.DataFrame: A pandas DataFrame containing the historical candlestick data along with a new column 'VWAP', 
                        representing the Volume Weighted Average Price.
            """
        df = DataFetcher.fetch_data(self, interval, start_date, end_date)
        
        # Calculate VWAP ( (Price * Volume) / Volume )
        df['VWAP'] = np.cumsum(df['volume'] * ((df['high'] + df['low'] + df['close']) / 3)) / np.cumsum(df['volume'])
        
        return df
    # End of fetch_VWAP() ----------------------------------------------------------------------------------------------------------



    def VWAP(self, df):
        """
        This function is created to add a column to the dataframe to compute teh VWAP, the data frame should be created with 
        the class DataFetcher for consistency reasons (df = DataFetcher.fetch_data(self, interval, start_date, end_date))
        The newly added column is called "VWAP". The VWAP is computed as 
        VWAP = cumsum(Volume * (H + L + C)/3 ) / cumsum(Volume).
        
        This VWAP is implemented on a session basis (every session starts at midnight). 
        The function uses (where possible) vectors and numpy to be more efficient  
        """
        # Ensure the index is in datetime format
        #df = pd.DataFrame(df)
        df.index = pd.to_datetime(df.index, unit='ms')

        # Extract session date from index to reset VWAP daily
        df["session_date"] = df.index.date

        # Calculate Typical Price (TP)
        df['TP'] = (df['high'] + df['low'] + df['close']).values / 3  

        # Calculate session-based VWAP
        df['VWAP'] = df.groupby('session_date', group_keys=False).apply(
            lambda g: np.cumsum(g['volume'] * g['TP']) / np.cumsum(g['volume'])
        )

        # Drop columns created for the VWAP creation 
        df = df.drop(columns= ["TP","session_date"])

        #Return
        return df

    # End of VWAP() ----------------------------------------------------------------------------------------------------------------


    def RSI(self, df, period=14, column = "close"):
        """
        Calculate the Relative Strength Index (RSI) for a given dataset.
        
        Parameters:
        - df (pd.Series): Series of closing prices
        - period (int): Lookback period for RSI (default=14)
        - columns (str): Column from which to compute the RSI. It should not be changed (default = "close")
        
        Returns:
        - pd.Series: RSI values
        """
        #df = pd.DataFrame(df)
        # Ensure the 'close' column exists in the dataset
        if column not in df.columns:
            raise ValueError(f"The dataset must contain a {column} column.")
        
        # Initialise the function
        delta = df[column].diff(1)

        gain = np.where(delta > 0 , delta, 0)
        loss = np.where(delta < 0 , -delta, 0)

        # As a series 
        gain = pd.Series(gain, index = df.index)
        loss = pd.Series(loss, index = df.index)

        # Create averages
        avg_gain = gain.rolling(window=period, min_periods=1).mean()
        avg_loss = loss.rolling(window=period, min_periods=1).mean()

        # Compute the Relative Strenght
        RS = avg_gain / avg_loss

        # Compute the Index (RSI)
        RSI = 100 - ( 100/(1+RS) )

        # Remove the first na value 
        if np.isnan(RSI[0]):
            RSI[0] = 0

        # Assing the RSI 
        df["RSI"] = RSI 

        # Return
        return df
    # End of RSI()--------------------------------------------------------------------------------------------------------------------------



    def SMA(self, df, period=14, column = "close"):
        """
    Calculate the Simple Moving Average (SMA) for a given DataFrame.

    Parameters:
    - df (pd.DataFrame): DataFrame containing stock data.
    - column (str): Column name for closing prices (default="close").
    - period (int): Lookback period for SMA (default=14).

    Returns:
    - pd.Series: SMA values added as a new column in the DataFrame.
        """
        #df = pd.DataFrame(df)
        # Ensure the 'close' column exists in the dataset
        if column not in df.columns:
            raise ValueError(f"The dataset must contain a {column} column.")
        
        # Calcualte it 
        df["SMA"] = df[column].rolling(window = period, min_periods=1).mean()

        return df
    # End of SMA()--------------------------------------------------------------------------------------------------------------------------




    def ATR(self, df, period = 14):
        """
        This function to add a column to a dataframe, The column contains the Average True Range (ATR), computed as 
        TR = max(H - L ; |H-C_prev| ; |L - C_prev|)
        ATR = 1/n * cumsum_1_to_n(TR_i)

        This is then smoothed with the Wilder's smoothing method
        ATR_i = ( (ATR_t-1 x (n-1))+ TR_i )/ n 
        This method allow to give to past observations less weight

        Teh computations are vectorized with numpys for optimized efficiency.

        Paramteres:
        df (pd.DataFrame): Dataframe created with the DataFetcher class (df = DataFetcher.fetch_data(self, interval, start_date, end_date))
        period (int): smoothing period over which compute the cumsum()
        """
        high_low = df["high"].values - df["low"].values
        high_close = np.abs(df["high"].values - df["close"].shift(1).fillna(df["close"].iloc[0]).values)
        low_close = np.abs(df['low'].values - df['low'].shift(1).fillna(df['close'].iloc[0]).values)

        # Define the true range
        true_range = np.maximum(high_low, high_close, low_close)

        # Wilder's smoothing method
        atr = np.empty_like(true_range) # Creates random values (faster than a vector with 0s)
        atr[:period] = np.mean(true_range[:period]) # This is the ATR until time i
        for i in range(period, len(atr)):  # For the rest, I use the Wilder's smoothing approach
            atr[i] = ( atr[i-1] * (period - 1) + true_range[i] ) / period

        # Return
        df["ATR"] = atr # Add a column to the dataframe
        return df
    #End of ATR() ----------------------------------------------------------------------------------------------------------------



    def fetch_VWAP_session(self, interval, start_date, end_date, time_session = "TV"):
        """
        Fetches the historical candlestick data and calculates the Volume Weighted Average Price (VWAP).
        This function calculate the VWAP for every session. It means that every day the calculation starts again. This is 
        more informative for trading, but it is slower and not applicable to time frames > 1 DAY 
        
        This function retrieves the market data using the `fetch_data` method of the `DataFetcher` class, 
        then calculates the VWAP using the formula: VWAP = (Price * Volume) / Volume, where Price is the typical price 
        (average of high, low, and close).

        Parameters:
            interval (str): The time interval for the candlestick data (e.g., "1DAY", "1HOUR").
            start_date (str): The starting date for the data retrieval (e.g., "1 Jan, 2025").
            end_date (str): The ending date for the data retrieval (e.g., "3 Jan, 2025").
            time_session (str): The desired time at what the session should start. The possible inputs are "TV" (tradin view)
            in which the VWAP indicator starts at 19, and "Midnight", in which the VWAP indicator start at 00:00. Baisc value is set to
            "TV".

        Returns:
            pd.DataFrame: A pandas DataFrame containing the historical candlestick data along with a new column 'VWAP', 
                        representing the Volume Weighted Average Price.
        """
        
        df = DataFetcher.fetch_data(self, interval, start_date, end_date)

        # Ensure the index is in datetime format
        df.index = pd.to_datetime(df.index, unit='ms')

        # Extract session date from index to reset VWAP daily
        if time_session == "TV":
            df['session_date'] = (df.index - pd.Timedelta(hours=19)).date 
        if time_session == "Midnight": 
            df["session_date"] = df.index.date

        # Calculate Typical Price (TP)
        df['TP'] = (df['high'] + df['low'] + df['close']) / 3  

        # Calculate session-based VWAP
        df['VWAP'] = df.groupby('session_date', group_keys=False).apply(
            lambda g: (g['volume'] * g['TP']).cumsum() / g['volume'].cumsum()
        )

        # Keep only relevant columns (index remains as timestamp)
        df = df[['open', 'high', 'low', 'close', 'volume', 'VWAP']]

        return df
    # End of fetch_VWAP_session() ----------------------------------------------------------------------------------------------------------

# %%
# Define the Data Fetcher

## 
API_key = "D2e3mW7aVMG1PnhhuVHayY9YqvVcr7JrKgBj3vrUQvNk6Fzb09Sb73eJ6YK53o3k"
API_secret = "I4ou2Q5R3H8Ypydlm3MTjjOe5zhCZK0pcGHl6hZn0eDpGsbyLkpclwXHEqoztkzL" 
client = Client(API_key, API_secret)
BTC_str = "BTCUSDT"
DataFetcher_BTC = DataFetcher(client, BTC_str)

# Last variables to be set up 
starting_date = "01 Nov, 2024"
ending_date = "02 Jan, 2025"
time_f = "1MIN"

# fetch the data
#df_VWAP = DataFetcher_BTC.fetch_VWAP_session(start_date= starting_date, end_date= ending_date,interval= time_f)
df_norm = DataFetcher_BTC.fetch_data(start_date= starting_date, end_date= ending_date,interval= time_f)

# %%
df = df_norm

df = DataFetcher_BTC.VWAP(df)
df = DataFetcher_BTC.ATR(df)
df = DataFetcher_BTC.RSI(df)
df = DataFetcher_BTC.SMA(df)
# inputs for the next function
#target_RR = 1
"""
This is to be used if the test set that we want to ulitze is based on a cutoff date and not on a random sample: 
starting_date1 = "03 Jan, 2025"
ending_date1 = "01 Mar, 2025"
df_test = DataFetcher_BTC.fetch_data(start_date = starting_date1, end_date = ending_date1, interval= time_f)

df_test = DataFetcher_BTC.VWAP(df_test)
df_test = DataFetcher_BTC.ATR(df_test)
df_test = DataFetcher_BTC.RSI(df_test)
df_test = DataFetcher_BTC.SMA(df_test)
"""
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_18844\3363453065.py:134: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# C:\Users\gabri\AppData\Local\Temp\ipykernel_18844\3363453065.py:185: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\gabri\AppData\Local\Temp\ipykernel_18844\3363453065.py:186: FutureWarning:
#
# Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
# '\nThis is to be used if the test set that we want to ulitze is based on a cutoff date and not on a random sample: \nstarting_date1 = "03 Jan, 2025"\nending_date1 = "01 Mar, 2025"\ndf_test = DataFetcher_BTC.fetch_data(start_date = starting_date1, end_date = ending_date1, interval= time_f)\n\ndf_test = DataFetcher_BTC.VWAP(df_test)\ndf_test = DataFetcher_BTC.ATR(df_test)\ndf_test = DataFetcher_BTC.RSI(df_test)\ndf_test = DataFetcher_BTC.SMA(df_test)\n'

# %% [markdown]
# # From here, we try the tradin env

# %%
 # (TradinEnv) The previous trading environment

import gym # This is the Open AI gym library utilized for Reinforcement Learning environment
from gym import spaces
from stable_baselines3 import PPO # Library to train AI models in reinforcement learning  

class TradinEnv(gym.Env):
    """
    Custom Trading Environment for Reinforcement Learning.
    

    The agent can take actions (buy, sell, hold) based on market indicators.
    The goal is to maximize profit while using stop-loss and take-profit levels.
    """
    def __init__(self,df):
        """
        Initialize the trading environment.

        Parameters:
        df (pd.DataFrame): Historical market data with indicators.
        execution_delay = 1
        """
        super(TradinEnv, self).__init__()

        # Store the dataset and set initial step 
        self.df = df
        self.current_step = 0 

        # Define action space: 3 possible actions (0 = Hold, 1 = Buy, 2 = Sell)
        self.action_space = spaces.Discrete(3)

        # Define the observation space: all column of the dataset that I have 
        self.observation_space = spaces.Box(  
            low = np.inf, high=np.inf, shape=( len(df.columns), ), dtype = np.float32 # Meaning it can take any number from all the columns of the df
        )

        # Initialize some trading varaibles (Note: still part of the class, just initializing them)
        self.balance = 1000 # Initial capital
        self.position = None # No active trade 
        self.entry_price = 0 # Price at which a trade was openend 


    def reset(self): 
        """
        Reset the environment at the start of a new episode. This function resets everything 
        when starts a new round 

        Returns:
        np.array: First observation (market indicators at step 0)
        """
        self.current_step = 0        
        self.balance = 1000
        self.position = None
        self.entry_price = 0
        return self._next_observation()

    def _next_observation(self):
        """
        Retrieve the current market state.

        Returns:
        np.array: Market indicators at the current step.
        """
        return self.df.iloc[self.current_step].values
    
    def step(self, action):
        """
        Execute an action (buy, sell, hold) and update the environment.

        Parameters:
        action (int): 0 (Hold), 1 (Buy), 2 (Sell)

        Returns:
        tuple: (new observation, reward, done flag, info)
        """
        current_price = self.df.iloc[self.current_step]["close"]
        entry_long = self.df.iloc[self.current_step].shift(1)["high"]
        entry_short = self.df.iloc[self.current_step].shift(1)["low"]
        atr_percent = self.df.iloc[self.current_step]["ATR"] / self.df.iloc[self.current_step]["close"] # It is used for stop loss and take profit
        previous_low = self.df["low"].shift(1)[self.current_step] # For the stop loss (long) and take profit (short)
        previous_high = self.df["high"].shift(1)[self.current_step] # For the stop loss (short) adn the take profit (long)

        reward = 0 # Default reward
        done = False # Track if episode is finished 

        # Execute action 
        if action == 1: # Buy (long)
            if self.position is None: # If the trade is closed 
                self.position = "long" # Change the position to long 
                self.entry_price = entry_long # Which is the previous high 
                self.stop_loss = previous_low - (atr_percent * self.entry_price)   
                self.take_profit = self.entry_price + (atr_percent * self.entry_price) 
        
        elif action == 2: # Sell (short)
            if self.position is None: # If the trade is closed 
                self.position = "short"
                self.entry_price = entry_short # This is the previous low.  
                self.stop_loss = previous_high + (atr_percent * self.entry_price) # Current price will be the entry price
                self.take_profit = self.entry_price - (atr_percent * self.entry_price)  

        
        # Cheeck if we are in a long or short setting 
        if self.position == "long": 
            if current_price >= self.take_profit: # Current price to be changed with whatever above TP
                reward = 1 # Define the reward for the supervised learning 
                self.position = None # Close the position
                self.balance = self.balance + (self.take_profit - self.entry_price) 
            elif current_price <= self.stop_loss:
                reward = -1 # Penalty for the loss
                self.position = None
                self.balance = self.balance + (self.stop_loss - self.entry_price) 

        elif self.position == "short":
            if current_price <= self.take_profit: # same comment as line 265 (tbd) 
                reward = 1 
                self.position = None
                self.balance = self.balance + (self.entry_price - self.take_profit)
            elif current_price >= self.stop_loss:
                reward = -1 
                self.position = None
                self.balance = self.balance + (self.entry_price - self.stop_loss )

        # Now we move to the next step 
        self.current_step += 1 # current step = current step + 1 
        if self.current_step >= len(self.df) - 1: # Condition to stop the loop
            done = True  

        return self._next_observation(), reward, done, {}
    
        
    def render(self):
        """
        Print the current state of the environment (for debugging).
        """
        print(f"Step: {self.current_step}, Balance: {self.balance}, Position: {self.position}")

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO # Library to train AI models in reinforcement learning  


class TradinEnv_v1(gym.Env):
    """
    Custom Trading Environment for Reinforcement Learning.

    The agent can take actions (buy, sell, hold) based on market indicators.
    The goal is to maximize profit while using stop-loss and take-profit levels.
    """
    def __init__(self, df):
        """
        Initialize the trading environment.

        Parameters:
        df (pd.DataFrame): Historical market data with indicators.
        """
        super(TradinEnv_v1, self).__init__()

        # Store the dataset and set initial step 
        self.df = df
        self.current_step = 1
        self.balance = 1000 # Initial capital
        self.position = None # No active trade   
        self.pending_orders = []  # Store multiple pending orders
        self.execution_delay = 1 

        # Define action space: 3 possible actions (0 = Hold, 1 = Buy, 2 = Sell)
        self.action_space = spaces.Discrete(3)

        # Define the observation space: all columns of the dataset
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(len(df.columns),), dtype=np.float32
        )

    def reset(self): 
        """
        Reset the environment at the start of a new episode.

        Returns:
        np.array: First observation (market indicators at step 0)
        """
        self.current_step = 1
        self.balance = 1000
        self.position = None
        self.pending_orders = []
        return self._next_observation()

    def _next_observation(self):
        """
        Retrieve the current market state.

        Returns:
        np.array: Market indicators at the current step.
        """
        return self.df.iloc[self.current_step].values

    def step(self, action):
        """
        Execute an action (buy, sell, hold) and update the environment.

        Parameters:
        action (int): 0 (Hold), 1 (Buy), 2 (Sell)

        Returns:
        tuple: (new observation, reward, done flag, info)
        """
        current_price = self.df.iloc[self.current_step]['close'] #TBR
        high = self.df.iloc[self.current_step]['high']
        low = self.df.iloc[self.current_step]['low']
        atr_percent = self.df.iloc[self.current_step]["ATR"] / self.df.iloc[self.current_step]["close"]
        previous_high = self.df["high"].shift(1)[self.current_step]
        previous_low = self.df["low"].shift(1)[self.current_step]

        reward = 0
        done = False

        # Handle new actions
        if action == 1:  # Buy limit order
            self.position = "long"
            print(f"Step check: Position (t): {self.position}, Action: {action}, Current step: {self.current_step}")#TBR
            stop_price = previous_low   
            self._place_order("buy", previous_high, stop_price, atr_percent)

        elif action == 2:  # Sell limit order
            self.position = "short" 
            print(f"Step check: Position (t): {self.position}, Action: {action}, Current step: {self.current_step}")#TBR
            stop_price = previous_high
            self._place_order("sell", previous_low, stop_price, atr_percent)


        # Process existing pending orders
        self._execute_pending_orders(high, low)

        # Move to the next step
        self.current_step += 1
        if self.current_step >= len(self.df) - 1:
            done = True
        
        return self._next_observation(), reward, done, {}

    def _place_order(self, order_type, entry_price, stop_price, atr):
        """
        Place a limit order. By using a function, I am able to identify every order which is placed (and therefore executed)
        through the step at which is placed or executed 

        Parameters:
        order_type (str): 'buy' or 'sell'.
        entry_price (float): Price at which the order will be executed.
        """
        # Define the variable 
        self.pending_order = None

        # Define a converter to invert the sign of buy and sell 
        if order_type == "buy":
            buy_sell_converter = 1
        elif order_type == "sell":
            buy_sell_converter = -1 

        order = {
            "type": order_type,
            "entry_price": entry_price, 
            "step_placed": self.current_step,
            "take_profit": entry_price + ( (entry_price * atr) * buy_sell_converter ), #Wrong, should depend on RR 
            "stop_loss" : stop_price - ( (stop_price * atr) * buy_sell_converter )
        }
        self.pending_orders.append(order)

    def _execute_pending_orders(self, high, low):
        """
        Execute any pending limit orders if the price condition is met.

        Parameters:
        current_price (float): Current market price.
        high (float): Current high price.
        low (float): Current low price.
        """
        executed_orders = []

        for order in self.pending_orders:
            # Buy orders loop  
            if order["type"] == "buy":
                # Execute pending order (profit)
                if high >= order["take_profit"] and abs(order["step_placed"] - self.current_step) >= self.execution_delay: 
                    executed_orders.append(order)
                    self.balance +=  (self.balance*( (order["take_profit"] - order["entry_price"])/order["take_profit"] ) )
                    print(f"Executed order : {executed_orders} \n")#TBR   
                # Stop loss trigger (loss)
                elif low <= order["stop_loss"] and abs(order["step_placed"] - self.current_step) >= self.execution_delay:
                    executed_orders.append(order)
                    self.balance += (self.balance*( (order["stop_loss"] - order["entry_price"])/order["stop_loss"] ) )
                    print(f"Executed order : {executed_orders} \n")#TBR

            # Sell order
            elif order["type"] == "sell":
                # Execute pending order (profit)
                if low <= order["take_profit"] and abs(order["step_placed"] - self.current_step) >= self.execution_delay: 
                    executed_orders.append(order)
                    self.balance +=  ( self.balance* ( (order["entry_price"] - order["take_profit"])/order["entry_price"] ) )
                    print(f"Executed order : {executed_orders} \n")#TBR   
                # Stop loss trigger (loss)
                elif high >= order["stop_loss"] and abs(order["step_placed"] - self.current_step) >= self.execution_delay:
                    executed_orders.append(order)
                    self.balance += (self.balance*( (order["entry_price"] - order["stop_loss"])/order["entry_price"] ) )
                    print(f"Executed order : {executed_orders} \n")#TBR
                    
        # Remove executed orders from the list
        self.pending_orders = [o for o in self.pending_orders if o not in executed_orders]
        

    def render(self):
        """
        Print the current state of the environment (for debugging).
        """
        print(f"Step: {self.current_step}, Position (t-1): {self.position}, Balance: {self.balance}, Pending Orders: {self.pending_orders}")

# This class compared to the older one adds the element of "future", meaning that the order instead of being
# immediately executed, is opened as a pending order, and then executed at a later time. This code introduces
# limit orders by introducing the term self.pending_order["step_placed"] = self.current_step. This code stores the
# current step in a given place.

# %% [markdown]
# ## This section to test the results of the two different trading environments
# ### 1. Training on the first Env

# %%
# Here we test the results of the first environment (Immediate market orders)
from utils import train_test_split

# Define training and test set on a random split 
df_train, df_test = train_test_split(df,test_size=0.2)

#Create the environment N1 
env = TradinEnv(df_train) 
test_env = TradinEnv(df_test)

# Train the model 
model = PPO("MlpPolicy", env, verbose = 1) # PPO model to train the AI 
model.save("trading_ppo_model")
model = PPO.load("trading_ppo_model")
# Out:
# Using cpu device
# d:\Gabri\Documents\Programmazione\Python\Algo project\.venv\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning:
#
# You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ### 2. Training on the second environment

# %%
#Create the environment N1 
env_v1 = TradinEnv_v1(df_train) 
test_env_v1 = TradinEnv_v1(df_test)

# Train the model 
model_v1 = PPO("MlpPolicy", env_v1, verbose = 1) # PPO model to train the AI 
model_v1.save("trading_ppo_model")
model_v1 = PPO.load("trading_ppo_model")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ### 3. Compare the differences

# %%
# Testing on the old environment (TradinEnv)
obs = test_env.reset() # reset function put the state back to the initial state and return the first step of the dataset
done = False 

while not done:  # Keep running until done is True 
    action, _ = model.predict(obs) # Prediction using the trained model. Action is buy (1) or sell (2)
    obs, reward, done, _ = test_env.step(action) # Apply the action in the environment 
    test_env.render() # Print the state for debugging 


######################  Error as it starts from 1012 ###########################################
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_18844\3842954110.py:80: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\gabri\AppData\Local\Temp\ipykernel_18844\3842954110.py:81: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# Step: 17820, Balance: 15817838.57697876, Position: None
# Step: 17821, Balance: 15848230.210470699, Position: None
# Step: 17822, Balance: 15848230.210470699, Position: long
# Step: 17823, Balance: 15848305.342844203, Position: None
# Step: 17824, Balance: 15848305.342844203, Position: None
# Step: 17825, Balance: 15853162.14683592, Position: None
# Step: 17826, Balance: 15868991.484146742, Position: None
# Step: 17827, Balance: 15868991.484146742, Position: short
# Step: 17828, Balance: 15868414.007023234, Position: None
# Step: 17829, Balance: 15868414.007023234, Position: short
# Step: 17830, Balance: 15868458.963680003, Position: None
# Step: 17831, Balance: 15868458.963680003, Position: None
# Step: 17832, Balance: 15868458.963680003, Position: None
# Step: 17833, Balance: 15868491.577652475, Position: None
# Step: 17834, Balance: 15868491.577652475, Position: None
# Step: 17835, Balance: 15868491.577652475, Position: long
# Step: 17836, Balance: 15868491.577652475, Position: long
# Step: 17837, Balance: 15868491.577652475, Position: long
# Step: 17838, Balance: 15855905.11115985, Position: None
# Step: 17839, Balance: 15881283.85295937, Position: None
# Step: 17840, Balance: 15881283.85295937, Position: long
# Step: 17841, Balance: 15876313.835257841, Position: None
# Step: 17842, Balance: 15876432.538084647, Position: None
# Step: 17843, Balance: 15888869.98502977, Position: None
# Step: 17844, Balance: 15888869.98502977, Position: None
# Step: 17845, Balance: 15888869.98502977, Position: long
# Step: 17846, Balance: 15886676.406798635, Position: None
# Step: 17847, Balance: 15886676.406798635, Position: None
# Step: 17848, Balance: 15886676.406798635, Position: short
# Step: 17849, Balance: 15886676.406798635, Position: short
# Step: 17850, Balance: 15886721.870096624, Position: None
# Step: 17851, Balance: 15902198.212263677, Position: None
# Step: 17852, Balance: 15902198.212263677, Position: long
# Step: 17853, Balance: 15902305.814225186, Position: None
# Step: 17854, Balance: 15902305.814225186, Position: None
# Step: 17855, Balance: 15902305.814225186, Position: None

# %%
# Testing on the second (TradinEnv_v1)
obs_v1 = test_env_v1.reset()
done = False
    
while not done: 
    action, _ = model_v1.predict(obs_v1)
    test_env_v1.render()
    obs_v1, reward, done, _ = test_env_v1.step(action)
# Out:
# Step: 1, Position (t-1): None, Balance: 1000, Pending Orders: []
# Step: 2, Position (t-1): None, Balance: 1000, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 2
# Step: 3, Position (t-1): long, Balance: 1000, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(97189.04), 'step_placed': 2, 'take_profit': np.float64(97228.82206606133), 'stop_loss': np.float64(97055.1164843244)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(97189.04), 'step_placed': 2, 'take_profit': np.float64(97228.82206606133), 'stop_loss': np.float64(97055.1164843244)}]
#
# Step: 4, Position (t-1): long, Balance: 1000.4091591897957, Pending Orders: []
# Step: 5, Position (t-1): long, Balance: 1000.4091591897957, Pending Orders: []
# Step: 6, Position (t-1): long, Balance: 1000.4091591897957, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 6
# Step: 7, Position (t-1): long, Balance: 1000.4091591897957, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(98445.98), 'step_placed': 6, 'take_profit': np.float64(98568.39766778455), 'stop_loss': np.float64(98153.75375224375)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(98445.98), 'step_placed': 6, 'take_profit': np.float64(98568.39766778455), 'stop_loss': np.float64(98153.75375224375)}]
#
# Step: 8, Position (t-1): long, Balance: 1001.6516239046132, Pending Orders: []
# Step: 9, Position (t-1): long, Balance: 1001.6516239046132, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 9
# Step: 10, Position (t-1): long, Balance: 1001.6516239046132, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(99989.99), 'step_placed': 9, 'take_profit': np.float64(100028.40342468841), 'stop_loss': np.float64(99811.63035948997)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(99989.99), 'step_placed': 9, 'take_profit': np.float64(100028.40342468841), 'stop_loss': np.float64(99811.63035948997)}]
#
# Step: 11, Position (t-1): long, Balance: 999.861710014694, Pending Orders: []
# Step: 12, Position (t-1): long, Balance: 999.861710014694, Pending Orders: []
# Step: 13, Position (t-1): long, Balance: 999.861710014694, Pending Orders: []
# Step: 14, Position (t-1): long, Balance: 999.861710014694, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 14
# Step: 15, Position (t-1): long, Balance: 999.861710014694, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(69291.0), 'step_placed': 14, 'take_profit': np.float64(69334.20554079626), 'stop_loss': np.float64(69170.83247783095)}]
# Step check: Position (t): short, Action: 2, Current step: 15
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(69291.0), 'step_placed': 14, 'take_profit': np.float64(69334.20554079626), 'stop_loss': np.float64(69170.83247783095)}]
#
# Step: 16, Position (t-1): short, Balance: 1000.4847728386741, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(76690.0), 'step_placed': 15, 'take_profit': np.float64(76627.53169918284), 'stop_loss': np.float64(76792.33074458325)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(76690.0), 'step_placed': 15, 'take_profit': np.float64(76627.53169918284), 'stop_loss': np.float64(76792.33074458325)}]
#
# Step: 17, Position (t-1): short, Balance: 1001.2997237286554, Pending Orders: []
# Step: 18, Position (t-1): short, Balance: 1001.2997237286554, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 18
# Step: 19, Position (t-1): long, Balance: 1001.2997237286554, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(75255.98), 'step_placed': 18, 'take_profit': np.float64(75356.77714323727), 'stop_loss': np.float64(75027.37427195646)}]
# Step check: Position (t): long, Action: 1, Current step: 19
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(75255.98), 'step_placed': 18, 'take_profit': np.float64(75356.77714323727), 'stop_loss': np.float64(75027.37427195646)}]
#
# Step: 20, Position (t-1): long, Balance: 1002.6390611512774, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(95550.0), 'step_placed': 19, 'take_profit': np.float64(95670.53419649517), 'stop_loss': np.float64(95307.61970378712)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(95550.0), 'step_placed': 19, 'take_profit': np.float64(95670.53419649517), 'stop_loss': np.float64(95307.61970378712)}]
#
# Step: 21, Position (t-1): long, Balance: 1000.0892130552726, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 21
# Step: 22, Position (t-1): short, Balance: 1000.0892130552726, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(88330.0), 'step_placed': 21, 'take_profit': np.float64(88246.60288967224), 'stop_loss': np.float64(88505.48397248275)}]
# Step check: Position (t): long, Action: 1, Current step: 22
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(88330.0), 'step_placed': 21, 'take_profit': np.float64(88246.60288967224), 'stop_loss': np.float64(88505.48397248275)}]
#
# Step: 23, Position (t-1): long, Balance: 998.1023498384258, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(67800.0), 'step_placed': 22, 'take_profit': np.float64(67845.05732603415), 'stop_loss': np.float64(67686.98786420435)}]
# Step check: Position (t): long, Action: 1, Current step: 23
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(67800.0), 'step_placed': 22, 'take_profit': np.float64(67845.05732603415), 'stop_loss': np.float64(67686.98786420435)}]
#
# Step: 24, Position (t-1): long, Balance: 998.7652105502386, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(92600.16), 'step_placed': 23, 'take_profit': np.float64(92700.29654819482), 'stop_loss': np.float64(92400.14157962542)}]
# Step check: Position (t): long, Action: 1, Current step: 24
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(92600.16), 'step_placed': 23, 'take_profit': np.float64(92700.29654819482), 'stop_loss': np.float64(92400.14157962542)}]
#
# Step: 25, Position (t-1): long, Balance: 996.6031852943877, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(98512.01), 'step_placed': 24, 'take_profit': np.float64(98547.21250053479), 'stop_loss': np.float64(98311.79648594576)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(98512.01), 'step_placed': 24, 'take_profit': np.float64(98547.21250053479), 'stop_loss': np.float64(98311.79648594576)}]
#
# Step: 26, Position (t-1): long, Balance: 996.9591864766952, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 26
# Step: 27, Position (t-1): short, Balance: 996.9591864766952, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(98440.9), 'step_placed': 26, 'take_profit': np.float64(98269.50235192374), 'stop_loss': np.float64(98747.40247324339)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(98440.9), 'step_placed': 26, 'take_profit': np.float64(98269.50235192374), 'stop_loss': np.float64(98747.40247324339)}]
#
# Step: 28, Position (t-1): short, Balance: 998.6950143672378, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 28
# Step: 29, Position (t-1): short, Balance: 998.6950143672378, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(95685.85), 'step_placed': 28, 'take_profit': np.float64(95646.74632868063), 'stop_loss': np.float64(95753.64539189554)}]
# Step check: Position (t): short, Action: 2, Current step: 29
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(95685.85), 'step_placed': 28, 'take_profit': np.float64(95646.74632868063), 'stop_loss': np.float64(95753.64539189554)}]
#
# Step: 30, Position (t-1): short, Balance: 997.9874184177517, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(68490.0), 'step_placed': 29, 'take_profit': np.float64(68441.95439851197), 'stop_loss': np.float64(68552.93603977903)}]
# Step check: Position (t): short, Action: 2, Current step: 30
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(68490.0), 'step_placed': 29, 'take_profit': np.float64(68441.95439851197), 'stop_loss': np.float64(68552.93603977903)}]
#
# Step: 31, Position (t-1): short, Balance: 997.0703593454125, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(96210.49), 'step_placed': 30, 'take_profit': np.float64(96133.35173373729), 'stop_loss': np.float64(96380.6027502918)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(96210.49), 'step_placed': 30, 'take_profit': np.float64(96133.35173373729), 'stop_loss': np.float64(96380.6027502918)}]
#
# Step: 32, Position (t-1): short, Balance: 995.3074083297522, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 32
# Step: 33, Position (t-1): short, Balance: 995.3074083297522, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(97179.08), 'step_placed': 32, 'take_profit': np.float64(97103.92850190093), 'stop_loss': np.float64(97289.75895131414)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(97179.08), 'step_placed': 32, 'take_profit': np.float64(97103.92850190093), 'stop_loss': np.float64(97289.75895131414)}]
#
# Step: 34, Position (t-1): short, Balance: 996.077109409502, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 34
# Step: 35, Position (t-1): long, Balance: 996.077109409502, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(96566.9), 'step_placed': 34, 'take_profit': np.float64(96654.38543164554), 'stop_loss': np.float64(96379.08554452792)}]
# Step check: Position (t): short, Action: 2, Current step: 35
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(96566.9), 'step_placed': 34, 'take_profit': np.float64(96654.38543164554), 'stop_loss': np.float64(96379.08554452792)}]
#
# Step: 36, Position (t-1): short, Balance: 994.1360484536423, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(95921.53), 'step_placed': 35, 'take_profit': np.float64(95860.32172505738), 'stop_loss': np.float64(96030.7889168784)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(95921.53), 'step_placed': 35, 'take_profit': np.float64(95860.32172505738), 'stop_loss': np.float64(96030.7889168784)}]
#
# Step: 37, Position (t-1): short, Balance: 993.0036829890399, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 37
# Step: 38, Position (t-1): short, Balance: 993.0036829890399, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(96346.56), 'step_placed': 37, 'take_profit': np.float64(96117.30445671464), 'stop_loss': np.float64(96668.04448003347)}]
# Step check: Position (t): long, Action: 1, Current step: 38
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(96346.56), 'step_placed': 37, 'take_profit': np.float64(96117.30445671464), 'stop_loss': np.float64(96668.04448003347)}]
#
# Step: 39, Position (t-1): long, Balance: 995.3665239542805, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(95628.28), 'step_placed': 38, 'take_profit': np.float64(95695.90130665909), 'stop_loss': np.float64(95324.54577322917)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(95628.28), 'step_placed': 38, 'take_profit': np.float64(95695.90130665909), 'stop_loss': np.float64(95324.54577322917)}]
#
# Step: 40, Position (t-1): long, Balance: 992.1949706145349, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 40
# Step: 41, Position (t-1): long, Balance: 992.1949706145349, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(69221.14), 'step_placed': 40, 'take_profit': np.float64(69281.00666480862), 'stop_loss': np.float64(69116.59201177559)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(69221.14), 'step_placed': 40, 'take_profit': np.float64(69281.00666480862), 'stop_loss': np.float64(69116.59201177559)}]
#
# Step: 42, Position (t-1): long, Balance: 993.0523398502038, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 42
# Step: 43, Position (t-1): short, Balance: 993.0523398502038, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(76704.99), 'step_placed': 42, 'take_profit': np.float64(76678.99462005078), 'stop_loss': np.float64(76811.83276990922)}]
# Step check: Position (t): short, Action: 2, Current step: 43
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(76704.99), 'step_placed': 42, 'take_profit': np.float64(76678.99462005078), 'stop_loss': np.float64(76811.83276990922)}]
#
# Step: 44, Position (t-1): short, Balance: 991.669112205504, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(69470.0), 'step_placed': 43, 'take_profit': np.float64(69447.21853748178), 'stop_loss': np.float64(69514.63862784076)}]
# Step check: Position (t): long, Action: 1, Current step: 44
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(69470.0), 'step_placed': 43, 'take_profit': np.float64(69447.21853748178), 'stop_loss': np.float64(69514.63862784076)}]
#
# Step: 45, Position (t-1): long, Balance: 991.031905520015, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(98312.0), 'step_placed': 44, 'take_profit': np.float64(98356.05094742803), 'stop_loss': np.float64(98225.95787611643)}]
# Step check: Position (t): short, Action: 2, Current step: 45
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(98312.0), 'step_placed': 44, 'take_profit': np.float64(98356.05094742803), 'stop_loss': np.float64(98225.95787611643)}]
#
# Step: 46, Position (t-1): short, Balance: 991.4757612253736, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(95055.87), 'step_placed': 45, 'take_profit': np.float64(94997.97374058262), 'stop_loss': np.float64(95142.65384344464)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(95055.87), 'step_placed': 45, 'take_profit': np.float64(94997.97374058262), 'stop_loss': np.float64(95142.65384344464)}]
#
# Step: 47, Position (t-1): short, Balance: 990.5705664463311, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 47
# Step: 48, Position (t-1): short, Balance: 990.5705664463311, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(95178.37), 'step_placed': 47, 'take_profit': np.float64(95065.67183611888), 'stop_loss': np.float64(95385.48983383128)}]
# Step check: Position (t): long, Action: 1, Current step: 48
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(95178.37), 'step_placed': 47, 'take_profit': np.float64(95065.67183611888), 'stop_loss': np.float64(95385.48983383128)}]
#
# Step: 49, Position (t-1): long, Balance: 988.4149631183845, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(67759.99), 'step_placed': 48, 'take_profit': np.float64(67812.35315911709), 'stop_loss': np.float64(67627.69865507589)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(67759.99), 'step_placed': 48, 'take_profit': np.float64(67812.35315911709), 'stop_loss': np.float64(67627.69865507589)}]
#
# Step: 50, Position (t-1): long, Balance: 989.178194706382, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 50
# Step: 51, Position (t-1): long, Balance: 989.178194706382, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(97436.0), 'step_placed': 50, 'take_profit': np.float64(97461.94077886971), 'stop_loss': np.float64(97390.05454847321)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(97436.0), 'step_placed': 50, 'take_profit': np.float64(97461.94077886971), 'stop_loss': np.float64(97390.05454847321)}]
#
# Step: 52, Position (t-1): long, Balance: 988.7115326944656, Pending Orders: []
# Step: 53, Position (t-1): long, Balance: 988.7115326944656, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 53
# Step: 54, Position (t-1): short, Balance: 988.7115326944656, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(99460.0), 'step_placed': 53, 'take_profit': np.float64(99425.57195018539), 'stop_loss': np.float64(99504.44151477318)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(99460.0), 'step_placed': 53, 'take_profit': np.float64(99425.57195018539), 'stop_loss': np.float64(99504.44151477318)}]
#
# Step: 55, Position (t-1): short, Balance: 989.0537749013819, Pending Orders: []
# Step: 56, Position (t-1): short, Balance: 989.0537749013819, Pending Orders: []
# Step: 57, Position (t-1): short, Balance: 989.0537749013819, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 57
# Step: 58, Position (t-1): long, Balance: 989.0537749013819, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(87727.99), 'step_placed': 57, 'take_profit': np.float64(87775.31428557727), 'stop_loss': np.float64(87556.8125622494)}]
# Step check: Position (t): long, Action: 1, Current step: 58
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(87727.99), 'step_placed': 57, 'take_profit': np.float64(87775.31428557727), 'stop_loss': np.float64(87556.8125622494)}]
#
# Step: 59, Position (t-1): long, Balance: 987.1201310645323, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(91019.0), 'step_placed': 58, 'take_profit': np.float64(91043.94308321852), 'stop_loss': np.float64(90935.07308529476)}]
# Step check: Position (t): short, Action: 2, Current step: 59
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(91019.0), 'step_placed': 58, 'take_profit': np.float64(91043.94308321852), 'stop_loss': np.float64(90935.07308529476)}]
#
# Step: 60, Position (t-1): short, Balance: 987.3905699179254, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(76300.0), 'step_placed': 59, 'take_profit': np.float64(76260.51199611694), 'stop_loss': np.float64(76361.27927581915)}]
# Step check: Position (t): long, Action: 1, Current step: 60
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(76300.0), 'step_placed': 59, 'take_profit': np.float64(76260.51199611694), 'stop_loss': np.float64(76361.27927581915)}]
#
# Step: 61, Position (t-1): long, Balance: 986.5975610178568, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(98276.16), 'step_placed': 60, 'take_profit': np.float64(98366.19329024214), 'stop_loss': np.float64(98154.15602577192)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(98276.16), 'step_placed': 60, 'take_profit': np.float64(98366.19329024214), 'stop_loss': np.float64(98154.15602577192)}]
#
# Step: 62, Position (t-1): long, Balance: 985.3712367511971, Pending Orders: []
# Step: 63, Position (t-1): long, Balance: 985.3712367511971, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 63
# Step: 64, Position (t-1): short, Balance: 985.3712367511971, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(95737.45), 'step_placed': 63, 'take_profit': np.float64(95621.55052905709), 'stop_loss': np.float64(95900.67669586369)}]
# Step check: Position (t): short, Action: 2, Current step: 64
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(95737.45), 'step_placed': 63, 'take_profit': np.float64(95621.55052905709), 'stop_loss': np.float64(95900.67669586369)}]
#
# Step: 65, Position (t-1): short, Balance: 986.5641242264936, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(74190.0), 'step_placed': 64, 'take_profit': np.float64(74122.83910583965), 'stop_loss': np.float64(74334.81112387012)}]
# Step check: Position (t): long, Action: 1, Current step: 65
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(74190.0), 'step_placed': 64, 'take_profit': np.float64(74122.83910583965), 'stop_loss': np.float64(74334.81112387012)}]
#
# Step: 66, Position (t-1): long, Balance: 984.6384541955032, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(94092.62), 'step_placed': 65, 'take_profit': np.float64(94205.57204284542), 'stop_loss': np.float64(93889.65614032665)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(94092.62), 'step_placed': 65, 'take_profit': np.float64(94205.57204284542), 'stop_loss': np.float64(93889.65614032665)}]
#
# Step: 67, Position (t-1): long, Balance: 982.509934087307, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 67
# Step: 68, Position (t-1): short, Balance: 982.509934087307, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(90772.14), 'step_placed': 67, 'take_profit': np.float64(90709.1738473342), 'stop_loss': np.float64(90931.03264812789)}]
# Step check: Position (t): long, Action: 1, Current step: 68
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(90772.14), 'step_placed': 67, 'take_profit': np.float64(90709.1738473342), 'stop_loss': np.float64(90931.03264812789)}]
#
# Step: 69, Position (t-1): long, Balance: 980.7900935587143, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(96976.0), 'step_placed': 68, 'take_profit': np.float64(97107.09209271955), 'stop_loss': np.float64(96780.99442243816)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(96976.0), 'step_placed': 68, 'take_profit': np.float64(97107.09209271955), 'stop_loss': np.float64(96780.99442243816)}]
#
# Step: 70, Position (t-1): long, Balance: 982.1141351205855, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 70
# Step: 71, Position (t-1): long, Balance: 982.1141351205855, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(98000.0), 'step_placed': 70, 'take_profit': np.float64(98086.52993461025), 'stop_loss': np.float64(97856.6003233885)}]
# Step check: Position (t): short, Action: 2, Current step: 71
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(98000.0), 'step_placed': 70, 'take_profit': np.float64(98086.52993461025), 'stop_loss': np.float64(97856.6003233885)}]
#
# Step: 72, Position (t-1): short, Balance: 980.674938899723, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(95538.77), 'step_placed': 71, 'take_profit': np.float64(95328.72102878173), 'stop_loss': np.float64(95822.17990677034)}]
# Step check: Position (t): short, Action: 2, Current step: 72
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(95538.77), 'step_placed': 71, 'take_profit': np.float64(95328.72102878173), 'stop_loss': np.float64(95822.17990677034)}]
#
# Step: 73, Position (t-1): short, Balance: 977.7658267873776, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(97830.7), 'step_placed': 72, 'take_profit': np.float64(97727.25948594742), 'stop_loss': np.float64(98103.60951149024)}]
# Step check: Position (t): long, Action: 1, Current step: 73
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(97830.7), 'step_placed': 72, 'take_profit': np.float64(97727.25948594742), 'stop_loss': np.float64(98103.60951149024)}]
#
# Step: 74, Position (t-1): long, Balance: 975.0382413347497, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(107788.0), 'step_placed': 73, 'take_profit': np.float64(107876.43087968159), 'stop_loss': np.float64(107554.60814611001)}]
# Step check: Position (t): long, Action: 1, Current step: 74
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(107788.0), 'step_placed': 73, 'take_profit': np.float64(107876.43087968159), 'stop_loss': np.float64(107554.60814611001)}]
#
# Step: 75, Position (t-1): long, Balance: 972.9224232709657, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(98180.0), 'step_placed': 74, 'take_profit': np.float64(98243.06323595835), 'stop_loss': np.float64(98028.85337835838)}]
# Step check: Position (t): short, Action: 2, Current step: 75
# Step: 76, Position (t-1): short, Balance: 972.9224232709657, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(98180.0), 'step_placed': 74, 'take_profit': np.float64(98243.06323595835), 'stop_loss': np.float64(98028.85337835838)}, {'type': 'sell', 'entry_price': np.float64(95772.1), 'step_placed': 75, 'take_profit': np.float64(95732.0574452499), 'stop_loss': np.float64(95880.7212156767)}]
# Step check: Position (t): short, Action: 2, Current step: 76
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(98180.0), 'step_placed': 74, 'take_profit': np.float64(98243.06323595835), 'stop_loss': np.float64(98028.85337835838)}]
#
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(98180.0), 'step_placed': 74, 'take_profit': np.float64(98243.06323595835), 'stop_loss': np.float64(98028.85337835838)}, {'type': 'sell', 'entry_price': np.float64(95772.1), 'step_placed': 75, 'take_profit': np.float64(95732.0574452499), 'stop_loss': np.float64(95880.7212156767)}]
#
# Step: 77, Position (t-1): short, Balance: 972.4427908396476, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(98176.17), 'step_placed': 76, 'take_profit': np.float64(98082.85259647775), 'stop_loss': np.float64(98278.8462907881)}]
# Step check: Position (t): short, Action: 2, Current step: 77
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(98176.17), 'step_placed': 76, 'take_profit': np.float64(98082.85259647775), 'stop_loss': np.float64(98278.8462907881)}]
#
# Step: 78, Position (t-1): short, Balance: 971.4257739936345, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(101224.29), 'step_placed': 77, 'take_profit': np.float64(101071.89002924963), 'stop_loss': np.float64(101492.52410465259)}]
# Step check: Position (t): long, Action: 1, Current step: 78
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(101224.29), 'step_placed': 77, 'take_profit': np.float64(101071.89002924963), 'stop_loss': np.float64(101492.52410465259)}]
#
# Step: 79, Position (t-1): long, Balance: 972.8883207750719, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(100581.6), 'step_placed': 78, 'take_profit': np.float64(100634.87379562804), 'stop_loss': np.float64(100336.11806279972)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(100581.6), 'step_placed': 78, 'take_profit': np.float64(100634.87379562804), 'stop_loss': np.float64(100336.11806279972)}]
#
# Step: 80, Position (t-1): long, Balance: 970.5080561776922, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 80
# Step: 81, Position (t-1): short, Balance: 970.5080561776922, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(68983.99), 'step_placed': 80, 'take_profit': np.float64(68873.27405982293), 'stop_loss': np.float64(69132.77694437365)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(68983.99), 'step_placed': 80, 'take_profit': np.float64(68873.27405982293), 'stop_loss': np.float64(69132.77694437365)}]
#
# Step: 82, Position (t-1): short, Balance: 968.4148323997014, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 82
# Step: 83, Position (t-1): short, Balance: 968.4148323997014, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(87955.27), 'step_placed': 82, 'take_profit': np.float64(87880.58130332774), 'stop_loss': np.float64(88054.70969656766)}]
# Step check: Position (t): long, Action: 1, Current step: 83
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(87955.27), 'step_placed': 82, 'take_profit': np.float64(87880.58130332774), 'stop_loss': np.float64(88054.70969656766)}]
#
# Step: 84, Position (t-1): long, Balance: 967.3199704649311, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(95704.75), 'step_placed': 83, 'take_profit': np.float64(95750.60811891672), 'stop_loss': np.float64(95579.18009428571)}]
# Step check: Position (t): short, Action: 2, Current step: 84
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(95704.75), 'step_placed': 83, 'take_profit': np.float64(95750.60811891672), 'stop_loss': np.float64(95579.18009428571)}]
#
# Step: 85, Position (t-1): short, Balance: 966.0491259424418, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(90939.39), 'step_placed': 84, 'take_profit': np.float64(90840.79392305727), 'stop_loss': np.float64(91058.61842221188)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(90939.39), 'step_placed': 84, 'take_profit': np.float64(90840.79392305727), 'stop_loss': np.float64(91058.61842221188)}]
#
# Step: 86, Position (t-1): short, Balance: 964.7825624316763, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 86
# Step: 87, Position (t-1): short, Balance: 964.7825624316763, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(97788.11), 'step_placed': 86, 'take_profit': np.float64(97719.2534915377), 'stop_loss': np.float64(97964.53219645846)}]
# Step check: Position (t): long, Action: 1, Current step: 87
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(97788.11), 'step_placed': 86, 'take_profit': np.float64(97719.2534915377), 'stop_loss': np.float64(97964.53219645846)}]
#
# Step: 88, Position (t-1): long, Balance: 963.0419718959863, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(75788.0), 'step_placed': 87, 'take_profit': np.float64(75887.20305419544), 'stop_loss': np.float64(75614.93375608967)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(75788.0), 'step_placed': 87, 'take_profit': np.float64(75887.20305419544), 'stop_loss': np.float64(75614.93375608967)}]
#
# Step: 89, Position (t-1): long, Balance: 964.3009022700871, Pending Orders: []
# Step: 90, Position (t-1): long, Balance: 964.3009022700871, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 90
# Step: 91, Position (t-1): long, Balance: 964.3009022700871, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(102573.07), 'step_placed': 90, 'take_profit': np.float64(102624.82680613326), 'stop_loss': np.float64(102472.26795384006)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(102573.07), 'step_placed': 90, 'take_profit': np.float64(102624.82680613326), 'stop_loss': np.float64(102472.26795384006)}]
#
# Step: 92, Position (t-1): long, Balance: 963.3523187557016, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 92
# Step: 93, Position (t-1): long, Balance: 963.3523187557016, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(96780.0), 'step_placed': 92, 'take_profit': np.float64(96823.14507590204), 'stop_loss': np.float64(96650.67336146564)}]
# Step check: Position (t): short, Action: 2, Current step: 93
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(96780.0), 'step_placed': 92, 'take_profit': np.float64(96823.14507590204), 'stop_loss': np.float64(96650.67336146564)}]
#
# Step: 94, Position (t-1): short, Balance: 963.7815953391108, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(97690.03), 'step_placed': 93, 'take_profit': np.float64(97648.56040246272), 'stop_loss': np.float64(97749.48723008035)}]
# Step check: Position (t): long, Action: 1, Current step: 94
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(97690.03), 'step_placed': 93, 'take_profit': np.float64(97648.56040246272), 'stop_loss': np.float64(97749.48723008035)}]
#
# Step: 95, Position (t-1): long, Balance: 963.1950074952819, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(99683.99), 'step_placed': 94, 'take_profit': np.float64(99735.75598837055), 'stop_loss': np.float64(99576.26308728833)}]
# Step check: Position (t): short, Action: 2, Current step: 95
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(99683.99), 'step_placed': 94, 'take_profit': np.float64(99735.75598837055), 'stop_loss': np.float64(99576.26308728833)}]
#
# Step: 96, Position (t-1): short, Balance: 962.1529717602613, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(98325.84), 'step_placed': 95, 'take_profit': np.float64(98263.55244212456), 'stop_loss': np.float64(98418.28665099473)}]
# Step check: Position (t): short, Action: 2, Current step: 96
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(98325.84), 'step_placed': 95, 'take_profit': np.float64(98263.55244212456), 'stop_loss': np.float64(98418.28665099473)}]
#
# Step: 97, Position (t-1): short, Balance: 962.7624774498495, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(68847.09), 'step_placed': 96, 'take_profit': np.float64(68807.35175829467), 'stop_loss': np.float64(68927.76185477988)}]
# Step check: Position (t): long, Action: 1, Current step: 97
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(68847.09), 'step_placed': 96, 'take_profit': np.float64(68807.35175829467), 'stop_loss': np.float64(68927.76185477988)}]
#
# Step: 98, Position (t-1): long, Balance: 961.6343566422983, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(95751.55), 'step_placed': 97, 'take_profit': np.float64(95850.61037051443), 'stop_loss': np.float64(95628.95400363232)}]
# Step check: Position (t): short, Action: 2, Current step: 98
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(95751.55), 'step_placed': 97, 'take_profit': np.float64(95850.61037051443), 'stop_loss': np.float64(95628.95400363232)}]
#
# Step: 99, Position (t-1): short, Balance: 962.6281933565368, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(95072.01), 'step_placed': 98, 'take_profit': np.float64(94965.03918489895), 'stop_loss': np.float64(95462.18911040039)}]
# Step check: Position (t): long, Action: 1, Current step: 99
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(95072.01), 'step_placed': 98, 'take_profit': np.float64(94965.03918489895), 'stop_loss': np.float64(95462.18911040039)}]
#
# Step: 100, Position (t-1): long, Balance: 958.6775309888201, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(96430.09), 'step_placed': 99, 'take_profit': np.float64(96501.15546745887), 'stop_loss': np.float64(96237.02450842856)}]
# Step check: Position (t): short, Action: 2, Current step: 100
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(96430.09), 'step_placed': 99, 'take_profit': np.float64(96501.15546745887), 'stop_loss': np.float64(96237.02450842856)}]
#
# Step: 101, Position (t-1): short, Balance: 959.3835211560053, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(97624.0), 'step_placed': 100, 'take_profit': np.float64(97579.48796159399), 'stop_loss': np.float64(97770.00829492384)}]
# Step check: Position (t): long, Action: 1, Current step: 101
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(97624.0), 'step_placed': 100, 'take_profit': np.float64(97579.48796159399), 'stop_loss': np.float64(97770.00829492384)}]
#
# Step: 102, Position (t-1): long, Balance: 957.9486490743243, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(99947.72), 'step_placed': 101, 'take_profit': np.float64(100043.10965485149), 'stop_loss': np.float64(99792.68732256025)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(99947.72), 'step_placed': 101, 'take_profit': np.float64(100043.10965485149), 'stop_loss': np.float64(99792.68732256025)}]
#
# Step: 103, Position (t-1): long, Balance: 956.4604303691225, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 103
# Step: 104, Position (t-1): short, Balance: 956.4604303691225, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(97452.67), 'step_placed': 103, 'take_profit': np.float64(97378.53074746783), 'stop_loss': np.float64(97584.48309581654)}]
# Step check: Position (t): long, Action: 1, Current step: 104
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(97452.67), 'step_placed': 103, 'take_profit': np.float64(97378.53074746783), 'stop_loss': np.float64(97584.48309581654)}]
#
# Step: 105, Position (t-1): long, Balance: 955.1667355903855, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(81634.79), 'step_placed': 104, 'take_profit': np.float64(81686.53727898629), 'stop_loss': np.float64(81535.10312860063)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(81634.79), 'step_placed': 104, 'take_profit': np.float64(81686.53727898629), 'stop_loss': np.float64(81535.10312860063)}]
#
# Step: 106, Position (t-1): long, Balance: 955.7718203594487, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 106
# Step: 107, Position (t-1): short, Balance: 955.7718203594487, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(100984.81), 'step_placed': 106, 'take_profit': np.float64(100929.07542606487), 'stop_loss': np.float64(101135.78711029275)}]
# Step check: Position (t): short, Action: 2, Current step: 107
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(100984.81), 'step_placed': 106, 'take_profit': np.float64(100929.07542606487), 'stop_loss': np.float64(101135.78711029275)}]
#
# Step: 108, Position (t-1): short, Balance: 956.2993208338956, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(100666.66), 'step_placed': 107, 'take_profit': np.float64(100642.23010657397), 'stop_loss': np.float64(100741.37209300374)}]
# Step check: Position (t): long, Action: 1, Current step: 108
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(100666.66), 'step_placed': 107, 'take_profit': np.float64(100642.23010657397), 'stop_loss': np.float64(100741.37209300374)}]
#
# Step: 109, Position (t-1): long, Balance: 956.5313965826227, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(96110.0), 'step_placed': 108, 'take_profit': np.float64(96206.8024529505), 'stop_loss': np.float64(96001.66917019285)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(96110.0), 'step_placed': 108, 'take_profit': np.float64(96206.8024529505), 'stop_loss': np.float64(96001.66917019285)}]
#
# Step: 110, Position (t-1): long, Balance: 957.49385020495, Pending Orders: []
# Step: 111, Position (t-1): long, Balance: 957.49385020495, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 111
# Step: 112, Position (t-1): short, Balance: 957.49385020495, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(100956.42), 'step_placed': 111, 'take_profit': np.float64(100902.06755153161), 'stop_loss': np.float64(101090.99561540438)}]
# Step check: Position (t): short, Action: 2, Current step: 112
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(100956.42), 'step_placed': 111, 'take_profit': np.float64(100902.06755153161), 'stop_loss': np.float64(101090.99561540438)}]
#
# Step: 113, Position (t-1): short, Balance: 958.0093412965722, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(98935.23), 'step_placed': 112, 'take_profit': np.float64(98891.03258877416), 'stop_loss': np.float64(99026.91861753535)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(98935.23), 'step_placed': 112, 'take_profit': np.float64(98891.03258877416), 'stop_loss': np.float64(99026.91861753535)}]
#
# Step: 114, Position (t-1): short, Balance: 957.1215023327426, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 114
# Step: 115, Position (t-1): short, Balance: 957.1215023327426, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(105775.44), 'step_placed': 114, 'take_profit': np.float64(105737.90380213335), 'stop_loss': np.float64(105937.58040008227)}]
# Step check: Position (t): short, Action: 2, Current step: 115
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(105775.44), 'step_placed': 114, 'take_profit': np.float64(105737.90380213335), 'stop_loss': np.float64(105937.58040008227)}]
#
# Step: 116, Position (t-1): short, Balance: 957.4611530313734, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(69131.0), 'step_placed': 115, 'take_profit': np.float64(69095.97163043018), 'stop_loss': np.float64(69185.03799678513)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(69131.0), 'step_placed': 115, 'take_profit': np.float64(69095.97163043018), 'stop_loss': np.float64(69185.03799678513)}]
#
# Step: 117, Position (t-1): short, Balance: 956.7127292748909, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 117
# Step: 118, Position (t-1): long, Balance: 956.7127292748909, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(98527.82), 'step_placed': 117, 'take_profit': np.float64(98705.24203565171), 'stop_loss': np.float64(98330.6136548238)}]
# Step check: Position (t): short, Action: 2, Current step: 118
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(98527.82), 'step_placed': 117, 'take_profit': np.float64(98705.24203565171), 'stop_loss': np.float64(98330.6136548238)}]
#
# Step: 119, Position (t-1): short, Balance: 954.7940000642083, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(101399.3), 'step_placed': 118, 'take_profit': np.float64(101342.139516749), 'stop_loss': np.float64(101649.71936514013)}]
# Step check: Position (t): short, Action: 2, Current step: 119
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(101399.3), 'step_placed': 118, 'take_profit': np.float64(101342.139516749), 'stop_loss': np.float64(101649.71936514013)}]
#
# Step: 120, Position (t-1): short, Balance: 955.33223342922, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(69387.5), 'step_placed': 119, 'take_profit': np.float64(69370.2085030815), 'stop_loss': np.float64(69443.30109119168)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(69387.5), 'step_placed': 119, 'take_profit': np.float64(69370.2085030815), 'stop_loss': np.float64(69443.30109119168)}]
#
# Step: 121, Position (t-1): short, Balance: 954.563959877414, Pending Orders: []
# Step: 122, Position (t-1): short, Balance: 954.563959877414, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 122
# Step: 123, Position (t-1): long, Balance: 954.563959877414, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(90927.98), 'step_placed': 122, 'take_profit': np.float64(91043.2128666173), 'stop_loss': np.float64(90733.50768082298)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(90927.98), 'step_placed': 122, 'take_profit': np.float64(91043.2128666173), 'stop_loss': np.float64(90733.50768082298)}]
#
# Step: 124, Position (t-1): long, Balance: 952.5180093589663, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 124
# Step: 125, Position (t-1): short, Balance: 952.5180093589663, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(82646.01), 'step_placed': 124, 'take_profit': np.float64(82517.39844513655), 'stop_loss': np.float64(82921.32950320064)}]
# Step check: Position (t): long, Action: 1, Current step: 125
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(82646.01), 'step_placed': 124, 'take_profit': np.float64(82517.39844513655), 'stop_loss': np.float64(82921.32950320064)}]
#
# Step: 126, Position (t-1): long, Balance: 954.0002929225537, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(76474.0), 'step_placed': 125, 'take_profit': np.float64(76503.64615069532), 'stop_loss': np.float64(76395.05296885056)}]
# Step check: Position (t): long, Action: 1, Current step: 126
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(76474.0), 'step_placed': 125, 'take_profit': np.float64(76503.64615069532), 'stop_loss': np.float64(76395.05296885056)}]
#
# Step: 127, Position (t-1): long, Balance: 954.3699803540737, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(76236.75), 'step_placed': 126, 'take_profit': np.float64(76288.48041008528), 'stop_loss': np.float64(76150.29316951054)}]
# Step check: Position (t): long, Action: 1, Current step: 127
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(76236.75), 'step_placed': 126, 'take_profit': np.float64(76288.48041008528), 'stop_loss': np.float64(76150.29316951054)}]
#
# Step: 128, Position (t-1): long, Balance: 955.0171285236455, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(107103.09), 'step_placed': 127, 'take_profit': np.float64(107188.88391092171), 'stop_loss': np.float64(106975.22981288262)}]
# Step check: Position (t): long, Action: 1, Current step: 128
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(107103.09), 'step_placed': 127, 'take_profit': np.float64(107188.88391092171), 'stop_loss': np.float64(106975.22981288262)}]
#
# Step: 129, Position (t-1): long, Balance: 953.8756617657154, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(98458.08), 'step_placed': 128, 'take_profit': np.float64(98501.7851583571), 'stop_loss': np.float64(98256.32503049525)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(98458.08), 'step_placed': 128, 'take_profit': np.float64(98501.7851583571), 'stop_loss': np.float64(98256.32503049525)}]
#
# Step: 130, Position (t-1): long, Balance: 951.9170178311786, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 130
# Step: 131, Position (t-1): long, Balance: 951.9170178311786, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(97233.0), 'step_placed': 130, 'take_profit': np.float64(97461.56202194825), 'stop_loss': np.float64(96931.04091633354)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(97233.0), 'step_placed': 130, 'take_profit': np.float64(97461.56202194825), 'stop_loss': np.float64(96931.04091633354)}]
#
# Step: 132, Position (t-1): long, Balance: 948.9516107983694, Pending Orders: []
# Step: 133, Position (t-1): long, Balance: 948.9516107983694, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 133
# Step: 134, Position (t-1): short, Balance: 948.9516107983694, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(95188.32), 'step_placed': 133, 'take_profit': np.float64(95136.59021022456), 'stop_loss': np.float64(95255.918408842)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(95188.32), 'step_placed': 133, 'take_profit': np.float64(95136.59021022456), 'stop_loss': np.float64(95255.918408842)}]
#
# Step: 135, Position (t-1): short, Balance: 949.4673155332956, Pending Orders: []
# Step: 136, Position (t-1): short, Balance: 949.4673155332956, Pending Orders: []
# Step: 137, Position (t-1): short, Balance: 949.4673155332956, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 137
# Step: 138, Position (t-1): short, Balance: 949.4673155332956, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(68000.0), 'step_placed': 137, 'take_profit': np.float64(67967.40192019896), 'stop_loss': np.float64(68135.1472166125)}]
# Step check: Position (t): long, Action: 1, Current step: 138
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(68000.0), 'step_placed': 137, 'take_profit': np.float64(67967.40192019896), 'stop_loss': np.float64(68135.1472166125)}]
#
# Step: 139, Position (t-1): long, Balance: 947.5802881074299, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(94233.58), 'step_placed': 138, 'take_profit': np.float64(94299.60737251982), 'stop_loss': np.float64(94140.1918120369)}]
# Step check: Position (t): long, Action: 1, Current step: 139
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(94233.58), 'step_placed': 138, 'take_profit': np.float64(94299.60737251982), 'stop_loss': np.float64(94140.1918120369)}]
#
# Step: 140, Position (t-1): long, Balance: 948.2437716405918, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(88333.34), 'step_placed': 139, 'take_profit': np.float64(88420.7039340101), 'stop_loss': np.float64(88172.69861101719)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(88333.34), 'step_placed': 139, 'take_profit': np.float64(88420.7039340101), 'stop_loss': np.float64(88172.69861101719)}]
#
# Step: 141, Position (t-1): long, Balance: 949.1806823708313, Pending Orders: []
# C:\Users\gabri\AppData\Local\Temp\ipykernel_18844\1445849450.py:76: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\gabri\AppData\Local\Temp\ipykernel_18844\1445849450.py:77: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# Step check: Position (t): long, Action: 1, Current step: 141
# Step: 142, Position (t-1): long, Balance: 949.1806823708313, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(98875.98), 'step_placed': 141, 'take_profit': np.float64(98968.6347398722), 'stop_loss': np.float64(98675.47641795367)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(98875.98), 'step_placed': 141, 'take_profit': np.float64(98968.6347398722), 'stop_loss': np.float64(98675.47641795367)}]
#
# ...
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(98692.0), 'step_placed': 772, 'take_profit': np.float64(98558.9498575048), 'stop_loss': np.float64(98880.11427644057)}]
#
# Step: 774, Position (t-1): short, Balance: 811.6317658036871, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 774
# Step: 775, Position (t-1): long, Balance: 811.6317658036871, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(97988.97), 'step_placed': 774, 'take_profit': np.float64(98051.95592929116), 'stop_loss': np.float64(97899.33121380908)}]
# Step check: Position (t): long, Action: 1, Current step: 775
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(97988.97), 'step_placed': 774, 'take_profit': np.float64(98051.95592929116), 'stop_loss': np.float64(97899.33121380908)}]
#
# Step: 776, Position (t-1): long, Balance: 810.8886178636697, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(94443.01), 'step_placed': 775, 'take_profit': np.float64(94482.98920303489), 'stop_loss': np.float64(94355.3409933542)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(94443.01), 'step_placed': 775, 'take_profit': np.float64(94482.98920303489), 'stop_loss': np.float64(94355.3409933542)}]
#
# Step: 777, Position (t-1): long, Balance: 811.231734449689, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 777
# Step: 778, Position (t-1): short, Balance: 811.231734449689, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(101646.63), 'step_placed': 777, 'take_profit': np.float64(101484.42968776071), 'stop_loss': np.float64(101826.9792268197)}]
# Step check: Position (t): short, Action: 2, Current step: 778
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(101646.63), 'step_placed': 777, 'take_profit': np.float64(101484.42968776071), 'stop_loss': np.float64(101826.9792268197)}]
#
# Step: 779, Position (t-1): short, Balance: 812.526239153152, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(87630.89), 'step_placed': 778, 'take_profit': np.float64(87584.72363148554), 'stop_loss': np.float64(87801.74202176576)}]
# Step check: Position (t): long, Action: 1, Current step: 779
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(87630.89), 'step_placed': 778, 'take_profit': np.float64(87584.72363148554), 'stop_loss': np.float64(87801.74202176576)}]
#
# Step: 780, Position (t-1): long, Balance: 810.9420745886126, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(100910.93), 'step_placed': 779, 'take_profit': np.float64(100955.41509054601), 'stop_loss': np.float64(100847.32334263147)}]
# Step check: Position (t): long, Action: 1, Current step: 780
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(100910.93), 'step_placed': 779, 'take_profit': np.float64(100955.41509054601), 'stop_loss': np.float64(100847.32334263147)}]
#
# Step: 781, Position (t-1): long, Balance: 811.2994088790348, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(96376.49), 'step_placed': 780, 'take_profit': np.float64(96432.54957433879), 'stop_loss': np.float64(96289.64834118076)}]
# Step check: Position (t): long, Action: 1, Current step: 781
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(96376.49), 'step_placed': 780, 'take_profit': np.float64(96432.54957433879), 'stop_loss': np.float64(96289.64834118076)}]
#
# Step: 782, Position (t-1): long, Balance: 810.5677145829201, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(106000.0), 'step_placed': 781, 'take_profit': np.float64(106112.43340593563), 'stop_loss': np.float64(105845.9807506935)}]
# Step check: Position (t): long, Action: 1, Current step: 782
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(106000.0), 'step_placed': 781, 'take_profit': np.float64(106112.43340593563), 'stop_loss': np.float64(105845.9807506935)}]
#
# Step: 783, Position (t-1): long, Balance: 809.3882363445712, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(76588.0), 'step_placed': 782, 'take_profit': np.float64(76615.34417428402), 'stop_loss': np.float64(76498.68795797382)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(76588.0), 'step_placed': 782, 'take_profit': np.float64(76615.34417428402), 'stop_loss': np.float64(76498.68795797382)}]
#
# Step: 784, Position (t-1): long, Balance: 809.6771086747365, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 784
# Step: 785, Position (t-1): short, Balance: 809.6771086747365, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(99739.38), 'step_placed': 784, 'take_profit': np.float64(99702.25906612072), 'stop_loss': np.float64(99852.39917112373)}]
# Step check: Position (t): long, Action: 1, Current step: 785
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(99739.38), 'step_placed': 784, 'take_profit': np.float64(99702.25906612072), 'stop_loss': np.float64(99852.39917112373)}]
#
# Step: 786, Position (t-1): long, Balance: 809.9784537444039, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(96152.39), 'step_placed': 785, 'take_profit': np.float64(96245.26476704076), 'stop_loss': np.float64(96055.12947331382)}]
# Step check: Position (t): long, Action: 1, Current step: 786
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(96152.39), 'step_placed': 785, 'take_profit': np.float64(96245.26476704076), 'stop_loss': np.float64(96055.12947331382)}]
#
# Step: 787, Position (t-1): long, Balance: 809.1583108592962, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(93844.02), 'step_placed': 786, 'take_profit': np.float64(93902.39050064572), 'stop_loss': np.float64(93671.26069288907)}]
# Step check: Position (t): short, Action: 2, Current step: 787
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(93844.02), 'step_placed': 786, 'take_profit': np.float64(93902.39050064572), 'stop_loss': np.float64(93671.26069288907)}]
#
# Step: 788, Position (t-1): short, Balance: 807.6659680842222, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(90967.81), 'step_placed': 787, 'take_profit': np.float64(90864.89096617325), 'stop_loss': np.float64(91201.47679187235)}]
# Step check: Position (t): short, Action: 2, Current step: 788
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(90967.81), 'step_placed': 787, 'take_profit': np.float64(90864.89096617325), 'stop_loss': np.float64(91201.47679187235)}]
#
# Step: 789, Position (t-1): short, Balance: 805.5913362373445, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(92124.61), 'step_placed': 788, 'take_profit': np.float64(92090.33737781197), 'stop_loss': np.float64(92204.15946002193)}]
# Step check: Position (t): long, Action: 1, Current step: 789
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(92124.61), 'step_placed': 788, 'take_profit': np.float64(92090.33737781197), 'stop_loss': np.float64(92204.15946002193)}]
#
# Step: 790, Position (t-1): long, Balance: 805.8910360407392, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(98390.57), 'step_placed': 789, 'take_profit': np.float64(98443.48067983415), 'stop_loss': np.float64(98315.64116705603)}]
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(98390.57), 'step_placed': 789, 'take_profit': np.float64(98443.48067983415), 'stop_loss': np.float64(98315.64116705603)}]
#
# Step: 791, Position (t-1): long, Balance: 805.2768461306318, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 791
# Step: 792, Position (t-1): short, Balance: 805.2768461306318, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(95662.65), 'step_placed': 791, 'take_profit': np.float64(95643.50466404704), 'stop_loss': np.float64(95785.51608983484)}]
# Step check: Position (t): short, Action: 2, Current step: 792
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(95662.65), 'step_placed': 791, 'take_profit': np.float64(95643.50466404704), 'stop_loss': np.float64(95785.51608983484)}]
#
# Step: 793, Position (t-1): short, Balance: 805.4380092988517, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(76358.02), 'step_placed': 792, 'take_profit': np.float64(76314.16008015374), 'stop_loss': np.float64(76416.18813374251)}]
# Step check: Position (t): short, Action: 2, Current step: 793
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(76358.02), 'step_placed': 792, 'take_profit': np.float64(76314.16008015374), 'stop_loss': np.float64(76416.18813374251)}]
#
# Step: 794, Position (t-1): short, Balance: 804.824441452983, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(93712.45), 'step_placed': 793, 'take_profit': np.float64(93618.74193990418), 'stop_loss': np.float64(93919.15093480803)}]
# Step check: Position (t): short, Action: 2, Current step: 794
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(93712.45), 'step_placed': 793, 'take_profit': np.float64(93618.74193990418), 'stop_loss': np.float64(93919.15093480803)}]
#
# Step: 795, Position (t-1): short, Balance: 803.0492454741703, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(91175.49), 'step_placed': 794, 'take_profit': np.float64(91131.88633983002), 'stop_loss': np.float64(91359.79091489743)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(91175.49), 'step_placed': 794, 'take_profit': np.float64(91131.88633983002), 'stop_loss': np.float64(91359.79091489743)}]
#
# Step: 796, Position (t-1): short, Balance: 801.4259724799855, Pending Orders: []
# Step check: Position (t): long, Action: 1, Current step: 796
# Step: 797, Position (t-1): long, Balance: 801.4259724799855, Pending Orders: [{'type': 'buy', 'entry_price': np.float64(99530.0), 'step_placed': 796, 'take_profit': np.float64(99586.42888379673), 'stop_loss': np.float64(99443.59811913932)}]
# Step check: Position (t): short, Action: 2, Current step: 797
#  Executed order : [{'type': 'buy', 'entry_price': np.float64(99530.0), 'step_placed': 796, 'take_profit': np.float64(99586.42888379673), 'stop_loss': np.float64(99443.59811913932)}]
#
# Step: 798, Position (t-1): short, Balance: 800.7296510203586, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(104248.0), 'step_placed': 797, 'take_profit': np.float64(104212.22701156893), 'stop_loss': np.float64(104347.7949502074)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(104248.0), 'step_placed': 797, 'take_profit': np.float64(104212.22701156893), 'stop_loss': np.float64(104347.7949502074)}]
#
# Step: 799, Position (t-1): short, Balance: 801.0044236063302, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 799
# Step: 800, Position (t-1): short, Balance: 801.0044236063302, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(73920.01), 'step_placed': 799, 'take_profit': np.float64(73818.83763926971), 'stop_loss': np.float64(74165.36943603131)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(73920.01), 'step_placed': 799, 'take_profit': np.float64(73818.83763926971), 'stop_loss': np.float64(74165.36943603131)}]
#
# Step: 801, Position (t-1): short, Balance: 798.3456848746304, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 801
# Step: 802, Position (t-1): short, Balance: 798.3456848746304, Pending Orders: [{'type': 'sell', 'entry_price': np.float64(96350.0), 'step_placed': 801, 'take_profit': np.float64(96167.46677684879), 'stop_loss': np.float64(96670.78464255405)}]
#  Executed order : [{'type': 'sell', 'entry_price': np.float64(96350.0), 'step_placed': 801, 'take_profit': np.float64(96167.46677684879), 'stop_loss': np.float64(96670.78464255405)}]
#
# Step: 803, Position (t-1): short, Balance: 795.6876980022165, Pending Orders: []
# Step check: Position (t): short, Action: 2, Current step: 803
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 6
#       3 done = False
#       5 while not done:
# ----> 6     action, _ = model_v1.predict(obs_v1)
#       7     test_env_v1.render()
#       8     obs_v1, reward, done, _ = test_env_v1.step(action)
#
# File d:\Gabri\Documents\Programmazione\Python\Algo project\.venv\Lib\site-packages\stable_baselines3\common\base_class.py:557, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     537 def predict(
#     538     self,
#     539     observation: Union[np.ndarray, dict[str, np.ndarray]],
#    (...)
#     542     deterministic: bool = False,
#     543 ) -> tuple[np.ndarray, Optional[tuple[np.ndarray, ...]]]:
#     544     """
#     545     Get the policy action from an observation (and optional hidden state).
#     546     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     555         (used in recurrent policies)
#     556     """
# --> 557     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File d:\Gabri\Documents\Programmazione\Python\Algo project\.venv\Lib\site-packages\stable_baselines3\common\policies.py:368, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
# --> 368     actions = self._predict(obs_tensor, deterministic=deterministic)
#     369 # Convert to numpy, and reshape to the original action shape
#     370 actions = actions.cpu().numpy().reshape((-1, *self.action_space.shape))  # type: ignore[misc, assignment]
#
# File d:\Gabri\Documents\Programmazione\Python\Algo project\.venv\Lib\site-packages\stable_baselines3\common\policies.py:717, in ActorCriticPolicy._predict(self, observation, deterministic)
#     709 def _predict(self, observation: PyTorchObs, deterministic: bool = False) -> th.Tensor:
#     710     """
#     711     Get the action according to the policy for a given observation.
#     712
#    (...)
#     715     :return: Taken action according to the policy
#     716     """
# --> 717     return self.get_distribution(observation).get_actions(deterministic=deterministic)
#
# File d:\Gabri\Documents\Programmazione\Python\Algo project\.venv\Lib\site-packages\stable_baselines3\common\policies.py:750, in ActorCriticPolicy.get_distribution(self, obs)
#     743 def get_distribution(self, obs: PyTorchObs) -> Distribution:
#     744     """
#     745     Get the current policy distribution given the observations.
#     746
#     747     :param obs:
#     748     :return: the action distribution.
#     749     """
# --> 750     features = super().extract_features(obs, self.pi_features_extractor)
#     751     latent_pi = self.mlp_extractor.forward_actor(features)
#     752     return self._get_action_dist_from_latent(latent_pi)
#
# File d:\Gabri\Documents\Programmazione\Python\Algo project\.venv\Lib\site-packages\stable_baselines3\common\policies.py:130, in BaseModel.extract_features(self, obs, features_extractor)
#     122 def extract_features(self, obs: PyTorchObs, features_extractor: BaseFeaturesExtractor) -> th.Tensor:
#     123     """
#     124     Preprocess the observation if needed and extract features.
#     125
#    (...)
#     128     :return: The extracted features
#     129     """
# --> 130     preprocessed_obs = preprocess_obs(obs, self.observation_space, normalize_images=self.normalize_images)
#     131     return features_extractor(preprocessed_obs)
#
# File d:\Gabri\Documents\Programmazione\Python\Algo project\.venv\Lib\site-packages\stable_baselines3\common\preprocessing.py:121, in preprocess_obs(obs, observation_space, normalize_images)
#     119     if normalize_images and is_image_space(observation_space):
#     120         return obs.float() / 255.0
# --> 121     return obs.float()
#     123 elif isinstance(observation_space, spaces.Discrete):
#     124     # One hot encoding and convert to float to avoid errors
#     125     return F.one_hot(obs.long(), num_classes=int(observation_space.n)).float()
#
# KeyboardInterrupt:
